# %%
import youtube_dl
import pandas as pd
import numpy as np

# %%
queries = ["machine+learning", "data+science", "kaggle"]

# %%
ydl = youtube_dl.YoutubeDL({"ignoreerrors": True})

# %%
resultados = []
for query in queries:
    r = ydl.extract_info("ytsearchdate10:{}".format(query), download=False)
    for entry in r['entries']:
        if entry is not None:
            entry['query'] = query
    resultados += r['entries']
resultados = [e for e in resultados if e is not None]
# Out:
# [download] Downloading playlist: machine+learning
# [youtube:search:date] query "machine+learning": Downloading page 1
# [youtube:search:date] playlist machine+learning: Downloading 10 videos
# [download] Downloading video 1 of 10
# [youtube] KuzqnWHLZ44: Downloading webpage
# [download] Downloading video 2 of 10
# [youtube] nHGj_u0P9F0: Downloading webpage
# [download] Downloading video 3 of 10
# [youtube] P6saD97uWSs: Downloading webpage
# [download] Downloading video 4 of 10
# [youtube] ypylh84RWW8: Downloading webpage
# [download] Downloading video 5 of 10
# [youtube] YeZHhdnBP7w: Downloading webpage
# [download] Downloading video 6 of 10
# [youtube] yrkdni-CQw0: Downloading webpage
# [download] Downloading video 7 of 10
# [youtube] 3LdmTckwHqc: Downloading webpage
# [download] Downloading video 8 of 10
# [youtube] uncsDr9QnU4: Downloading webpage
# [download] Downloading video 9 of 10
# [youtube] eIg5WMYCmWE: Downloading webpage
# [download] Downloading video 10 of 10
# [youtube] Vl_x1ZdeuXc: Downloading webpage
# [download] Finished downloading playlist: machine+learning
# [download] Downloading playlist: data+science
# [youtube:search:date] query "data+science": Downloading page 1
# [youtube:search:date] playlist data+science: Downloading 10 videos
# [download] Downloading video 1 of 10
# [youtube] jx6Uo7dkRGQ: Downloading webpage
# [download] Downloading video 2 of 10
# [youtube] F8oGiBEse2M: Downloading webpage
# [download] Downloading video 3 of 10
# [youtube] 8ud4m07xTAA: Downloading webpage
# [download] Downloading video 4 of 10
# [youtube] 3mYWGOVC-yw: Downloading webpage
# [download] Downloading video 5 of 10
# [youtube] w564MnjtB7I: Downloading webpage
# [download] Downloading video 6 of 10
# [youtube] qU44M6dTWnk: Downloading webpage
# [download] Downloading video 7 of 10
# [youtube] J6LwLquZgt8: Downloading webpage
# [download] Downloading video 8 of 10
# [youtube] RyAKEODhZFc: Downloading webpage
# [download] Downloading video 9 of 10
# [youtube] yym5NJE3374: Downloading webpage
# [youtube] yym5NJE3374: Downloading m3u8 information
# [download] Downloading video 10 of 10
# [youtube] YhkwM_cYS3I: Downloading webpage
# [download] Finished downloading playlist: data+science
# [download] Downloading playlist: kaggle
# [youtube:search:date] query "kaggle": Downloading page 1
# [youtube:search:date] playlist kaggle: Downloading 10 videos
# [download] Downloading video 1 of 10
# [youtube] pUSi5xexT4Q: Downloading webpage
# [download] Downloading video 2 of 10
# [youtube] kSRFicHq1TU: Downloading webpage
# [download] Downloading video 3 of 10
# [youtube] hFaUAD4lUmU: Downloading webpage
# ERROR: This live event will begin in 3 hours.
# [download] Downloading video 4 of 10
# [youtube] 9KOifkY2rqI: Downloading webpage
# [download] Downloading video 5 of 10
# [youtube] VzLsXy_694s: Downloading webpage
# [download] Downloading video 6 of 10
# [youtube] jKYbUUWuyuI: Downloading webpage
# [download] Downloading video 7 of 10
# [youtube] 5oayOIZ0oi0: Downloading webpage
# [download] Downloading video 8 of 10
# [youtube] cceyTV357uU: Downloading webpage
# [download] Downloading video 9 of 10
# [youtube] vigBR79CW_Y: Downloading webpage
# [download] Downloading video 10 of 10
# [youtube] _tmzOU5PCqs: Downloading webpage
# [download] Finished downloading playlist: kaggle

# %%
df = pd.DataFrame(resultados)

# %%
df['upload_date'] = pd.to_datetime(df['upload_date'])
df['tempo_desde_pub'] = (pd.to_datetime("2021-02-10") -
                         df['upload_date']) / np.timedelta64(1, 'D')

# %%
#pd.set_option("display.max_columns", 73)
#df.tail()
df.head()
# Out:
#             id                                              title  \
# 0  KuzqnWHLZ44  PRESENTATION ON "IOT BASED MACHINE LEARNING TE...
# 1  nHGj_u0P9F0                 Machine Learning for Saving Bees 🐝
# 2  P6saD97uWSs  AI Masterclass on Quantum Machine Learning wit...
# 3  ypylh84RWW8  Which projects are right for Artificial Intell...
# 4  YeZHhdnBP7w  The MOST IMPORTANT topic in Machine Learning r...
#
#                                              formats  \
# 0  [{'asr': 48000, 'filesize': 7237727, 'format_i...
# 1  [{'asr': 44100, 'filesize': 1399584, 'format_i...
# 2  [{'asr': 48000, 'filesize': 49626876, 'format_...
# 3  [{'asr': 48000, 'filesize': 2613199, 'format_i...
# 4  [{'asr': 48000, 'filesize': 3058788, 'format_i...
#
#                                           thumbnails  \
# 0  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 1  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 2  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 3  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
# 4  [{'height': 94, 'url': 'https://i.ytimg.com/vi...
#
#                                          description upload_date  \
# 0  PRESENTER: IBRAHEAM YAHYA ISMAIL FATHAIL COURS...  2021-02-11
# 1                                                     2021-02-11
# 2  Synthetic Intelligence Forum is excited to con...  2021-02-11
# 3  This is an excerpt from the course Artificial ...  2021-02-11
# 4  Today we're discussing the most important topi...  2021-02-11
#
#                        uploader               uploader_id  \
# 0   CSIT2020 - Ibraheam Fathail  UCDfUYJulJuCBmCZKQOr-OjQ
# 1                    All in Oll  UCdV22Rk91QGAAmuUPKnEZ9g
# 2  Synthetic Intelligence Forum  UC8oMaBaY6L6KRjvoQWVYCWg
# 3                     Madecraft  UCw4qG2I9wW_xv3VFDFNitWw
# 4             Karolina Sowinska  UCAxnMry1lETl47xQWABvH7g
#
#                                         uploader_url  \
# 0  http://www.youtube.com/channel/UCDfUYJulJuCBmC...
# 1  http://www.youtube.com/channel/UCdV22Rk91QGAAm...
# 2  http://www.youtube.com/channel/UC8oMaBaY6L6KRj...
# 3  http://www.youtube.com/channel/UCw4qG2I9wW_xv3...
# 4  http://www.youtube.com/channel/UCAxnMry1lETl47...
#
#                  channel_id  ... abr   ext             query  url  \
# 0  UCDfUYJulJuCBmCZKQOr-OjQ  ... NaN  webm  machine+learning  NaN
# 1  UCdV22Rk91QGAAmuUPKnEZ9g  ... NaN  webm  machine+learning  NaN
# 2  UC8oMaBaY6L6KRjvoQWVYCWg  ... NaN  webm  machine+learning  NaN
# 3  UCw4qG2I9wW_xv3VFDFNitWw  ... NaN   mp4  machine+learning  NaN
# 4  UCAxnMry1lETl47xQWABvH7g  ... NaN   mp4  machine+learning  NaN
#
#    manifest_url tbr protocol preference http_headers tempo_desde_pub
# 0           NaN NaN      NaN        NaN          NaN            -1.0
# 1           NaN NaN      NaN        NaN          NaN            -1.0
# 2           NaN NaN      NaN        NaN          NaN            -1.0
# 3           NaN NaN      NaN        NaN          NaN            -1.0
# 4           NaN NaN      NaN        NaN          NaN            -1.0
#
# [5 rows x 58 columns]

# %%
colunas = ['title', 'upload_date', 'view_count']
df[colunas].to_feather("raw_data.feather")

# %%
df[colunas].to_csv("raw_data_sem_labels.csv")
